# %%
import pandas as pd

# %%
out = pd.read_csv('out.csv', sep=',',index_col = None)
out1 = pd.read_csv('out1.csv', sep=',',index_col = None)
out2 = pd.read_csv('out2.csv', sep=',',index_col = None)
prediction1 = out1['prediction']
prediction2 = out2['prediction']

# %%
out['prediction_1'] = prediction1
out['prediction_2'] = prediction2

# %%
out[out['prediction'] != out['gold_label']]
# Out:
#       Unnamed: 0        target_word  gold_label  prediction  prediction_1  \
# 2              2            shelled           1           0             1
# 4              4           sparking           1           0             1
# 9              9            intense           1           0             0
# 11            11           bloodied           1           0             1
# 14            14            victims           1           0             0
# 15            15           flooding           1           0             1
# 17            17          hospitals           0           1             1
# 19            19           violence           1           0             1
# 20            20            restive           1           0             0
# 22            22           province           1           0             1
# 26            26            eroding           1           0             0
# 28            28    internationally           0           1             1
# ...

# %%
out_s = pd.read_csv('out_s.csv', sep=',',index_col=None)
out_s1 = pd.read_csv('out_s1.csv', sep=',',index_col=None)
out_s2 = pd.read_csv('out_s2.csv', sep=',',index_col=None)
gold_label = out_s2['gold_label']
prediction_s1 = out1['prediction']
prediction_s2 = out2['prediction']
out_s['prediction_1'] = prediction1
out_s['prediction_2'] = prediction2

# %%
out_s['gold_label'] = gold_label
out_s[out_s['prediction'] != out_s['gold_label']]
# Out:
#       Unnamed: 0    target_word  prediction  prediction_1  prediction_2  \
# 1              1        Bronces           0             0             0
# 2              2          Riace           0             1             1
# 3              3        griegas           0             1             1
# 9              9           a. C           0             0             1
# 11            11        exponen           0             1             1
# 12            12          Magna           0             1             1
# 16            16          Regio           0             1             1
# 19            19       Calabria           0             1             1
# 20            20       Poseidón           0             0             0
# 30            30         auriga           0             0             1
# 35            35      cercanías           0             0             0
# 37            37    encontradas           1             0             0
# ...
